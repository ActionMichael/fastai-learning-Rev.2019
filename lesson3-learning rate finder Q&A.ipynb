# %%
提問:有沒有什麼方式使用learn.lr_find()這個方法，讓它返回一個建議的值，而不是僅僅畫出一張圖，然後通過觀察這張圖來選擇學習率？ 
    (還有一些關於解讀學習率尋找器圖像的其他問題) 

答案是沒有這樣的方法，為什麼說沒有？是因為這更取決於經驗。
就像你能看到的，我說過，如何解讀學習率圖像，取決於現在是第幾階段，和它的形狀是什麼樣的。
我猜當只訓練最後的幾層時（在你解凍前），它的圖像是這樣的：



你確實可以創建一些方法，找出最陡的向下的斜坡來找出學習率。這基本上，在任何時候都是可行的。
但是對於這種，就需要很多的實驗：


但好消息是你可以做些實驗。顯然，如果線是向上的，我們不想要它。
幾乎可以確定，你不希望正好在最底部的點這裡，因為你需要它繼續向下。
你可以從這個位置的1/10的地方開始嘗試，然後再縮小1/10。多試幾次，找出最好的那個。

幾週之內，你會發現，你可以每次都能找出最好的學習率。
但在這個階段，你仍然需要多做一些嘗試，來培養對不同形狀的感覺，培養如何處理它們的感覺。
可能在這個視頻發布的時候，有些人可以做出好用的自動learning rate finder，但現在還沒有。
這可能不是一個非常難的工作。這會是一個有意思的項目：收集所有不同的數據集，可能要抓去我們數據集頁面的所有數據集。
嘗試找出一些簡單的方法，和我所有講過的方法做對比。這會是一個很有趣的項目，我確信這是可能的，但現在我們還沒有這樣一個工具。
